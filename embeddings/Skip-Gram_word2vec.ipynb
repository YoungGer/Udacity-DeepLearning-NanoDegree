# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:02, 13.2MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
from random import random

counter_int_words = Counter(int_words)
N = len(int_words)
t = 1e-5
fw_int_words = {key:val/N for key, val in counter_int_words.items()}
pw = {k:1-np.sqrt(t/fw_int_words[k]) for k in fw_int_words}


train_words = [word for word in int_words if random()<1-pw[word]]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    R = np.random.randint(1, window_size+1)
    start = idx-R if (idx-R)>=0 else 0
    stop  = idx+R if (idx+R)<len(words) else len(words)-1
    
    target_words = set(words[start:idx] + words[idx+1:stop+1])
    return target_words

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name="inputs")
    labels = tf.placeholder(tf.int32, [None, None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], minval=-1, maxval=1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1)) # create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab)) # create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed, 
                                      n_sampled, n_vocab) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6641 0.1021 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6414 0.0944 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5138 0.0956 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5809 0.0941 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5365 0.0924 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.5348 0.0938 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.5775 0.0934 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5606 0.0931 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4378 0.0944 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4348 0.0930 sec/batch
# Nearest to where: schrader, transitioning, plundering, muted, yarmuk, meherabad, genteel, wct,
# Nearest to see: rosicrucians, tripling, drafts, conversant, armor, lector, greenery, aegean,
# Nearest to are: compensation, charge, spatial, complementary, bhaktivedanta, nicolson, governs, follicles,
# Nearest to first: ally, conjecture, poisonous, weighting, resorts, potent, modernism, guevara,
# Nearest to an: member, bilbo, caesium, hypomanic, solemnly, waterston, raoul, mbasogo,
# Nearest to have: phaethon, whoopi, contents, wasted, eider, ge, tver, romulus,
# Nearest to for: hue, but, gre, breasts, epidemiology, bowlers, publish, svetlana,
# Nearest to will: narrow, ligament, objecting, snorri, quail, exceptionally, guis, hypersonic,
# Nearest to defense: breisgau, perturbed, sapphic, numb, kaleidoscope, tulip, lab, petered,
# Nearest to centre: relate, sunrise, mathematics, seat, latgale, metaphysics, gallop, kirchner,
# Nearest to powers: spamming, akin, sundial, divinity, cocaine, olmsted, nicky, nominates,
# Nearest to primarily: departing, bessemer, india, stendhal, civilizations, predating, estonians, bleaches,
# Nearest to writers: abbadie, herzog, notated, yhwh, imola, elaborated, helix, deliberate,
# Nearest to behind: kankan, landfall, constructor, visigothic, idiocy, microprogram, lockport, antibacterial,
# Nearest to freedom: honeywell, wends, xor, hillman, publishers, multipoint, riding, diod,
# Nearest to engine: stagg, tier, bertrand, exotic, incubator, manassas, feats, pickguard,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4683 0.0952 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3633 0.0932 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.3277 0.0931 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2334 0.0926 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2059 0.0941 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1640 0.0940 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0854 0.0927 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0451 0.0927 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0139 0.0927 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 4.9686 0.0925 sec/batch
# Nearest to where: transitioning, ussr, schrader, scythians, muted, especially, plundering, wct,
# Nearest to see: drafts, lector, conversant, tripling, sunderland, inferior, counseling, armor,
# Nearest to are: charge, factor, spatial, complementary, compensation, outside, governs, nicolson,
# Nearest to first: ally, feeling, conjecture, potent, poisonous, resorts, annex, weighting,
# Nearest to an: member, functional, recently, sound, interpretive, hypomanic, distortion, kenny,
# Nearest to have: contents, phaethon, weapons, whoopi, ge, now, wasted, fairy,
# Nearest to for: hue, but, shape, reading, publish, benefits, statistical, vault,
# Nearest to will: act, efficient, narrow, massachusetts, romantic, they, are, exceptionally,
# Nearest to defense: lab, sapphic, breisgau, poaching, tulip, perturbed, edited, particularly,
# Nearest to centre: relate, mathematics, seat, metaphysics, sunrise, tremendous, catch, chapter,
# Nearest to powers: spamming, akin, sundial, divinity, daltrey, cocaine, nicky, foreword,
# Nearest to primarily: india, stendhal, predating, departing, closest, civilizations, responsible, brewster,
# Nearest to writers: deliberate, luck, josephus, mythology, hugo, yhwh, helix, abbadie,
# Nearest to behind: landfall, constructor, kankan, org, importance, prototype, scientist, microprogram,
# Nearest to freedom: honeywell, riding, publishers, hillman, abraham, resolution, generalise, diod,
# Nearest to engine: tier, bertrand, tenor, geneva, incubator, exotic, vowels, stagg,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9281 0.0938 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.8619 0.0939 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8755 0.0948 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8630 0.0927 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8235 0.0936 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8039 0.0932 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.7964 0.0947 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8080 0.0929 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7926 0.0928 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7617 0.0931 sec/batch
# Nearest to where: ussr, surely, transitioning, districts, schrader, muted, anomalies, scythians,
# Nearest to see: drafts, lector, conversant, tripling, armor, edwin, counseling, sunderland,
# Nearest to are: charge, factor, spatial, complementary, governs, prostration, normalization, compensation,
# Nearest to first: ally, resorts, systematically, conjecture, feeling, poisonous, potent, guevara,
# Nearest to an: member, interpretive, functional, shoulder, recently, caesium, domain, kenny,
# Nearest to have: wasted, phaethon, contents, eider, fairy, constitutive, whoopi, weapons,
# Nearest to for: hue, shape, but, vault, publish, computationally, statistical, slipped,
# Nearest to will: act, artifacts, exceptionally, efficient, interacting, romantic, ling, massachusetts,
# Nearest to defense: lab, sapphic, poaching, tulip, breisgau, perturbed, edited, zuse,
# Nearest to centre: relate, seat, mathematics, sunrise, metaphysics, latgale, tremendous, towers,
# Nearest to powers: spamming, akin, sundial, divinity, nicky, foreword, daltrey, taking,
# Nearest to primarily: india, departing, civilizations, predating, stendhal, closest, prodigy, bessemer,
# Nearest to writers: deliberate, hugo, josephus, mythology, elaborated, herzog, helix, luck,
# Nearest to behind: landfall, constructor, org, kankan, visigothic, microprogram, glasnevin, scientist,
# Nearest to freedom: honeywell, riding, publishers, hillman, abraham, resolution, revisions, generalise,
# Nearest to engine: tier, bertrand, tenor, exotic, geneva, vowels, incubator, pollutants,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7562 0.0947 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7473 0.0932 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7215 0.0934 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.6921 0.0922 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7161 0.0938 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7047 0.0925 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7264 0.0897 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7337 0.0921 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7223 0.0940 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6630 0.0925 sec/batch
# Nearest to where: ussr, schrader, yarmuk, surely, ado, anomalies, genteel, estes,
# Nearest to see: drafts, lector, armor, conversant, tripling, edwin, counseling, rosicrucians,
# Nearest to are: factor, charge, spatial, prostration, normalization, complementary, hotchkiss, governs,
# Nearest to first: ally, systematically, poisonous, guevara, gershom, weighting, unfretted, resorts,
# Nearest to an: member, domain, caesium, interpretive, waterston, recently, nanotechnology, kenny,
# Nearest to have: wasted, constitutive, eider, tver, phaethon, contents, whoopi, fairy,
# Nearest to for: hue, but, shape, belongs, computationally, breasts, benefits, whatsoever,
# Nearest to will: artifacts, interacting, ling, exceptionally, leanings, prot, snorri, pup,
# Nearest to defense: breisgau, lab, sapphic, tulip, perturbed, numb, poaching, zuse,
# Nearest to centre: relate, seat, sunrise, latgale, mathematics, miles, kirchner, metaphysics,
# Nearest to powers: spamming, sundial, akin, nicky, nominates, divinity, foreword, scalemajor,
# Nearest to primarily: departing, india, civilizations, stendhal, predating, bessemer, prodigy, referendum,
# Nearest to writers: hugo, elaborated, deliberate, josephus, mythology, herzog, helix, hiv,
# Nearest to behind: landfall, constructor, kankan, microprogram, org, visigothic, idiocy, lockport,
# Nearest to freedom: honeywell, riding, hillman, abraham, resolution, revisions, publishers, generalise,
# Nearest to engine: tier, bertrand, geometrically, tenor, exotic, geneva, coda, incubator,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6534 0.0933 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6806 0.0924 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6049 0.0931 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6577 0.0939 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6295 0.0930 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6494 0.0919 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6017 0.0694 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5344 0.0941 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5120 0.0935 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.4994 0.0932 sec/batch
# Nearest to where: schrader, ussr, ado, yarmuk, genteel, rigged, egyptologists, surely,
# Nearest to see: drafts, armor, conversant, tripling, lector, edwin, rosicrucians, omnibus,
# Nearest to are: factor, prostration, spatial, charge, normalization, complementary, hotchkiss, form,
# Nearest to first: weighting, guevara, gershom, ally, systematically, unfretted, resorts, choo,
# Nearest to an: member, caesium, interpretive, snowmobile, domain, solemnly, kenny, deceptive,
# Nearest to have: eider, wasted, constitutive, tver, phaethon, coset, fairy, linnaeus,
# Nearest to for: hue, but, shape, computationally, breasts, benefits, belongs, peltier,
# Nearest to will: interacting, artifacts, exceptionally, hypersonic, applets, pup, ling, efficient,
# Nearest to defense: numb, lab, sapphic, breisgau, perturbed, tulip, suffrage, bahri,
# Nearest to centre: seat, kirchner, relate, miles, sunrise, latgale, arrayed, towers,
# Nearest to powers: spamming, sundial, akin, nicky, nominates, scalemajor, divinity, olmsted,
# Nearest to primarily: departing, civilizations, stendhal, predating, fp, bessemer, india, referendum,
# Nearest to writers: hugo, herzog, elaborated, josephus, mythology, deliberate, heinrich, notated,
# Nearest to behind: landfall, constructor, microprogram, kankan, lockport, visigothic, glasnevin, org,
# Nearest to freedom: abraham, riding, hillman, resolution, honeywell, wends, revisions, publishers,
# Nearest to engine: tier, geometrically, bertrand, tenor, exotic, pickguard, coda, mieszko,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4921 0.0948 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4852 0.0922 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4713 0.0930 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5005 0.0935 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.5009 0.0933 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4782 0.0931 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4564 0.0922 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3790 0.0943 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4144 0.0937 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4433 0.0952 sec/batch
# Nearest to where: schrader, ado, ussr, yarmuk, genteel, pegging, anomalies, random,
# Nearest to see: drafts, conversant, tripling, armor, lector, rosicrucians, omnibus, efta,
# Nearest to are: factor, prostration, spatial, normalization, hotchkiss, form, complementary, bibliographical,
# Nearest to first: gershom, guevara, weighting, unfretted, systematically, ally, domino, poisonous,
# Nearest to an: member, caesium, domain, riordan, functional, snowmobile, deceptive, sound,
# Nearest to have: wasted, constitutive, eider, tver, phaethon, coset, mendel, ecb,
# Nearest to for: hue, but, vault, shape, computationally, belongs, breasts, benefits,
# Nearest to will: interacting, artifacts, hypersonic, wert, exceptionally, ling, stewie, applets,
# Nearest to defense: numb, sapphic, perturbed, lab, suffrage, breisgau, tulip, appeals,
# Nearest to centre: kirchner, miles, seat, sunrise, latgale, relate, towers, arrayed,
# Nearest to powers: sundial, spamming, scalemajor, akin, nominates, nicky, robed, divinity,
# Nearest to primarily: departing, civilizations, fp, india, abundant, predating, stendhal, bessemer,
# Nearest to writers: herzog, hugo, elaborated, deliberate, mythology, josephus, yhwh, abbadie,
# Nearest to behind: landfall, constructor, kankan, visigothic, microprogram, lockport, glasnevin, prototype,
# Nearest to freedom: riding, abraham, hillman, resolution, law, generalise, wends, fjord,
# Nearest to engine: tier, geometrically, pickguard, mieszko, bertrand, coda, tenor, incubator,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4354 0.0967 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4043 0.0929 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4416 0.0932 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3927 0.0931 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.4399 0.0932 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4519 0.0926 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3631 0.0937 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3539 0.0922 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.4276 0.0922 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3739 0.0930 sec/batch
# Nearest to where: schrader, genteel, ado, ussr, yarmuk, pegging, random, anomalies,
# Nearest to see: drafts, tripling, lector, conversant, omnibus, lexemes, armor, rosicrucians,
# Nearest to are: normalization, spatial, prostration, factor, hotchkiss, complementary, foci, form,
# Nearest to first: gershom, guevara, unfretted, garde, weighting, johnstone, domino, othello,
# Nearest to an: caesium, domain, member, functional, snowmobile, distortion, sound, infinitesimally,
# Nearest to have: wasted, constitutive, eider, tver, clout, coset, ecb, phaethon,
# Nearest to for: computationally, vault, hue, evaluates, shape, but, benefits, insider,
# Nearest to will: interacting, artifacts, pup, hypersonic, they, opponent, smarteiffel, wert,
# Nearest to defense: numb, sapphic, perturbed, suffrage, breisgau, bahri, lab, paganini,
# Nearest to centre: kirchner, seat, miles, latgale, sunrise, towers, lut, torpedo,
# Nearest to powers: sundial, scalemajor, nominates, robed, spamming, akin, divisive, tariff,
# Nearest to primarily: fp, departing, civilizations, india, referendum, abundant, allocates, bessemer,
# Nearest to writers: hugo, herzog, elaborated, fiction, mythology, josephus, yhwh, passionately,
# Nearest to behind: landfall, constructor, visigothic, microprogram, lockport, passes, kankan, glasnevin,
# Nearest to freedom: law, abraham, resolution, hillman, riding, fjord, generalise, honeywell,
# Nearest to engine: tier, geometrically, incubator, creates, exotic, mieszko, tenor, pickguard,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3995 0.0941 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.4094 0.0934 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3650 0.0933 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3504 0.0926 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3942 0.0955 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3900 0.0930 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3965 0.0932 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3840 0.0929 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3319 0.0927 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3387 0.0937 sec/batch
# Nearest to where: schrader, genteel, ussr, yarmuk, ado, pegging, corot, acquiesced,
# Nearest to see: drafts, tripling, lector, lexemes, omnibus, rosicrucians, conversant, serbia,
# Nearest to are: normalization, prostration, spatial, hotchkiss, foci, sex, follicles, factor,
# Nearest to first: gershom, guevara, garde, unfretted, othello, veered, domino, weighting,
# Nearest to an: member, caesium, domain, snowmobile, deceptive, infinitesimally, riordan, submitted,
# Nearest to have: constitutive, wasted, eider, clout, tver, ecb, phaethon, coset,
# Nearest to for: but, benefits, computationally, hue, evaluates, vault, belongs, shape,
# Nearest to will: interacting, hypersonic, smarteiffel, wert, opponent, kilowatt, pup, they,
# Nearest to defense: sapphic, numb, suffrage, perturbed, lab, bahri, appeals, training,
# Nearest to centre: kirchner, miles, seat, latgale, sunrise, towers, lut, torpedo,
# Nearest to powers: nominates, sundial, legislative, robed, scalemajor, divisive, taking, tariff,
# Nearest to primarily: fp, abundant, india, civilizations, allocates, trusteeship, referendum, bessemer,
# Nearest to writers: hugo, elaborated, herzog, fiction, yhwh, mythology, josephus, deliberate,
# Nearest to behind: landfall, constructor, lockport, biscuits, passes, visigothic, uncle, picks,
# Nearest to freedom: abraham, law, hillman, resolution, destiny, wends, honeywell, riding,
# Nearest to engine: tier, mieszko, incubator, geometrically, pickguard, exotic, preterite, burners,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3504 0.0932 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2878 0.0927 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3947 0.0930 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3786 0.0933 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3708 0.0921 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2868 0.0948 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.3003 0.0933 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3606 0.0929 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.2112 0.0934 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2903 0.0928 sec/batch
# Nearest to where: genteel, ussr, ado, schrader, yarmuk, pegging, corot, coronal,
# Nearest to see: tripling, drafts, lexemes, lector, serbia, omnibus, rosicrucians, efta,
# Nearest to are: normalization, prostration, spatial, hotchkiss, follicles, governs, foci, sex,
# Nearest to first: guevara, gershom, garde, unfretted, leon, othello, veered, domino,
# Nearest to an: caesium, member, domain, snowmobile, wildly, submitted, deceptive, waterston,
# Nearest to have: constitutive, wasted, eider, phaethon, tver, linnaeus, ecb, clout,
# Nearest to for: developer, but, belongs, vault, evaluates, regress, computationally, hue,
# Nearest to will: hypersonic, wert, opponent, interacting, smarteiffel, feu, pup, kilowatt,
# Nearest to defense: numb, sapphic, suffrage, perturbed, training, squadron, defence, lab,
# Nearest to centre: kirchner, miles, latgale, seat, towers, sunrise, lut, torpedo,
# Nearest to powers: nominates, sundial, divisive, appoint, scalemajor, legislative, circumvent, olmsted,
# Nearest to primarily: fp, civilizations, allocates, abundant, india, predating, bessemer, trusteeship,
# Nearest to writers: hugo, fiction, herzog, elaborated, yhwh, journeying, passionately, stories,
# Nearest to behind: landfall, constructor, lockport, visigothic, mudslides, passes, picks, biscuits,
# Nearest to freedom: abraham, hillman, law, publishers, resolution, destiny, confrontations, honeywell,
# Nearest to engine: tier, incubator, mieszko, powered, pickguard, preterite, turbojets, jaguar,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2993 0.0933 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2795 0.0924 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3445 0.0435 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2457 0.0942 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.2179 0.0906 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2674 0.0932 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2435 0.0925 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.2034 0.0930 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.2163 0.0936 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1786 0.0927 sec/batch
# Nearest to where: pegging, genteel, yarmuk, ado, ussr, coronal, sprawl, corot,
# Nearest to see: tripling, drafts, lexemes, lector, rosicrucians, serbia, omnibus, ricin,
# Nearest to are: normalization, prostration, foci, spatial, follicles, hotchkiss, bibliographical, sex,
# Nearest to first: guevara, gershom, garde, choo, domino, veered, unfretted, leon,
# Nearest to an: caesium, member, snowmobile, domain, wildly, speedup, riordan, moored,
# Nearest to have: eider, constitutive, wasted, tver, phaethon, ecb, schl, linnaeus,
# Nearest to for: computationally, evaluates, but, insider, gre, benefits, regress, vault,
# Nearest to will: opponent, hypersonic, wert, smarteiffel, interacting, kilowatt, feu, pup,
# Nearest to defense: numb, sapphic, suffrage, training, defence, perturbed, squadron, lab,
# Nearest to centre: kirchner, miles, seat, towers, latgale, sunrise, coasts, province,
# Nearest to powers: nominates, sundial, divisive, akin, olmsted, scalemajor, divinity, circumvent,
# Nearest to primarily: fp, civilizations, predating, allocates, abundant, bessemer, trusteeship, manufacturing,
# Nearest to writers: hugo, herzog, fiction, elaborated, yhwh, passionately, deliberate, journeying,
# Nearest to behind: landfall, passes, lockport, biscuits, mudslides, visigothic, picks, constructor,
# Nearest to freedom: abraham, publishers, hillman, destiny, law, licencing, confrontations, honeywell,
# Nearest to engine: powered, tier, incubator, turbojets, jaguar, preterite, pickguard, mieszko,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2631 0.0925 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.2342 0.0935 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2218 0.0945 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1449 0.0931 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1847 0.0927 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1779 0.0938 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1630 0.0942 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1613 0.0932 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1932 0.0925 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1810 0.0923 sec/batch
# Nearest to where: pegging, genteel, coronal, ussr, corot, ado, yarmuk, schrader,
# Nearest to see: drafts, lexemes, tripling, lector, ricin, omnibus, anta, rosicrucians,
# Nearest to are: normalization, prostration, sex, foci, follicles, spatial, hotchkiss, complementary,
# Nearest to first: guevara, gershom, garde, choo, othello, unfretted, fatou, johnstone,
# Nearest to an: caesium, member, domain, snowmobile, deceptive, submitted, a, speedup,
# Nearest to have: constitutive, wasted, eider, phaethon, linnaeus, ecb, tver, clout,
# Nearest to for: computationally, benefits, evaluates, but, vault, they, purer, shape,
# Nearest to will: opponent, wert, hypersonic, interacting, kilowatt, smarteiffel, they, go,
# Nearest to defense: numb, defence, suffrage, squadron, training, sapphic, perturbed, bahri,
# Nearest to centre: kirchner, towers, latgale, seat, miles, sunrise, lut, erina,
# Nearest to powers: nominates, sundial, divisive, scalemajor, tariff, appoint, robed, akin,
# Nearest to primarily: civilizations, fp, predating, allocates, abundant, bessemer, manufacturing, stepdaughter,
# Nearest to writers: hugo, fiction, herzog, elaborated, journeying, yhwh, passionately, deliberate,
# Nearest to behind: landfall, passes, picks, biscuits, mudslides, lockport, explodes, constructor,
# Nearest to freedom: abraham, publishers, law, destiny, licencing, hillman, money, concern,
# Nearest to engine: powered, tier, incubator, turbojets, pickguard, jaguar, preterite, mieszko,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1772 0.0921 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2004 0.0932 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1812 0.0920 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1544 0.0915 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1709 0.0928 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.2123 0.0925 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1853 0.0919 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1744 0.0919 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1439 0.0939 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1722 0.0923 sec/batch
# Nearest to where: genteel, corot, schrader, pegging, ado, coronal, moonchild, entitle,
# Nearest to see: lexemes, drafts, tripling, omnibus, anta, rosicrucians, lector, ricin,
# Nearest to are: normalization, foci, sex, prostration, follicles, form, non, spatial,
# Nearest to first: guevara, leon, gershom, garde, othello, fatou, choo, unfretted,
# Nearest to an: caesium, member, domain, infinitesimally, fold, snowmobile, a, moored,
# Nearest to have: constitutive, wasted, eider, linnaeus, tver, clout, mendel, phaethon,
# Nearest to for: computationally, evaluates, but, purer, benefits, testimonials, developer, regress,
# Nearest to will: opponent, hypersonic, wert, smarteiffel, anywhere, go, interacting, kilowatt,
# Nearest to defense: defence, numb, suffrage, training, squadron, sapphic, lab, perturbed,
# Nearest to centre: kirchner, latgale, towers, seat, miles, sunrise, lut, erina,
# Nearest to powers: nominates, sundial, divisive, appoint, legislative, akin, weyl, robed,
# Nearest to primarily: civilizations, allocates, predating, bessemer, fp, india, abundant, ameliorated,
# Nearest to writers: hugo, fiction, herzog, journeying, dramatists, elaborated, companion, passionately,
# Nearest to behind: landfall, passes, lockport, picks, biscuits, constructor, mudslides, idiocy,
# Nearest to freedom: abraham, publishers, licencing, destiny, hillman, law, concern, honeywell,
# Nearest to engine: turbojets, powered, tier, incubator, pickguard, jaguar, mieszko, preterite,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1728 0.0931 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1474 0.0920 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1780 0.0895 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1776 0.0898 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1314 0.0936 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.1593 0.0921 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1816 0.0933 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.1224 0.0963 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1936 0.0935 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2188 0.0923 sec/batch
# Nearest to where: corot, ussr, genteel, entitle, ado, scythians, yarmuk, rundown,
# Nearest to see: lexemes, tripling, drafts, serbia, rosicrucians, lector, omnibus, ricin,
# Nearest to are: normalization, foci, follicles, sex, prostration, governs, consists, form,
# Nearest to first: guevara, leon, gershom, garde, choo, othello, fatou, johnstone,
# Nearest to an: member, caesium, a, domain, deceptive, hoping, submitted, wildly,
# Nearest to have: constitutive, eider, wasted, tver, linnaeus, schl, rebekah, colonizing,
# Nearest to for: but, purer, evaluates, benefits, insider, they, regress, belongs,
# Nearest to will: opponent, smarteiffel, hypersonic, anywhere, go, wert, kilowatt, feu,
# Nearest to defense: defence, lab, sapphic, numb, squadron, suffrage, training, petered,
# Nearest to centre: kirchner, latgale, towers, seat, miles, erina, sunrise, lut,
# Nearest to powers: nominates, sundial, divisive, weyl, appoint, jubilees, akin, olmsted,
# Nearest to primarily: civilizations, allocates, predating, bessemer, fp, abundant, india, trusteeship,
# Nearest to writers: hugo, fiction, dramatists, journeying, herzog, novelists, steinberger, companion,
# Nearest to behind: landfall, passes, lockport, picks, biscuits, explodes, visigothic, mudslides,
# Nearest to freedom: abraham, licencing, publishers, destiny, law, hillman, concern, honeywell,
# Nearest to engine: turbojets, powered, tier, incubator, pickguard, generators, burners, tri,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.2255 0.0935 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1577 0.0929 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.1326 0.0913 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1269 0.0928 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0691 0.0925 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1712 0.0912 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1291 0.0923 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.1552 0.0922 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1823 0.0214 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.1362 0.0938 sec/batch
# Nearest to where: corot, entitle, ussr, yarmuk, rundown, coronal, districts, ado,
# Nearest to see: lexemes, drafts, tripling, rosicrucians, serbia, links, omnibus, lector,
# Nearest to are: normalization, follicles, consists, is, foci, prostration, bibliographical, hotchkiss,
# Nearest to first: leon, guevara, gershom, unfretted, veered, choo, fatou, garde,
# Nearest to an: caesium, a, member, deceptive, domain, wildly, snowmobile, infinitesimally,
# Nearest to have: constitutive, wasted, linnaeus, eider, ecb, colonizing, earthsea, tver,
# Nearest to for: evaluates, computationally, but, purer, regress, they, developer, benefits,
# Nearest to will: hypersonic, opponent, go, smarteiffel, anywhere, kilowatt, inflamed, pup,
# Nearest to defense: defence, squadron, lab, numb, sapphic, petered, training, suffrage,
# Nearest to centre: kirchner, towers, seat, latgale, miles, sunrise, erina, coasts,
# Nearest to powers: nominates, sundial, divisive, weyl, circumvent, akin, jubilees, scalemajor,
# Nearest to primarily: allocates, civilizations, predating, fp, bessemer, ameliorated, trusteeship, abundant,
# Nearest to writers: fiction, hugo, dramatists, journeying, steinberger, herzog, novelists, passionately,
# Nearest to behind: landfall, picks, passes, lockport, biscuits, tight, mudslides, glasnevin,
# Nearest to freedom: abraham, publishers, licencing, destiny, hillman, law, concern, refilled,
# Nearest to engine: powered, turbojets, tier, incubator, pickguard, rear, creates, tri,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0758 0.0939 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0674 0.0932 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0873 0.0938 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0720 0.0911 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0581 0.0919 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0568 0.0910 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.1120 0.0932 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0843 0.0920 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1019 0.0932 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 4.0131 0.0935 sec/batch
# Nearest to where: entitle, corot, yarmuk, districts, coronal, ussr, in, pegging,
# Nearest to see: lexemes, tripling, drafts, links, serbia, rosicrucians, ricin, girdler,
# Nearest to are: normalization, consists, is, follicles, prostration, non, branches, bibliographical,
# Nearest to first: guevara, leon, gershom, fatou, safely, veered, garde, domino,
# Nearest to an: caesium, a, member, domain, snowmobile, wildly, hoping, riordan,
# Nearest to have: wasted, constitutive, eider, linnaeus, earthsea, colonizing, ecb, rebekah,
# Nearest to for: they, but, computationally, purer, evaluates, benefit, testimonials, breasts,
# Nearest to will: go, hypersonic, anywhere, opponent, kilowatt, smarteiffel, reward, pup,
# Nearest to defense: defence, squadron, lab, numb, sapphic, training, petered, perturbed,
# Nearest to centre: kirchner, towers, seat, latgale, sunrise, erina, instantiated, miles,
# Nearest to powers: nominates, sundial, divisive, weyl, jubilees, olmsted, appoint, akin,
# Nearest to primarily: civilizations, allocates, predating, fp, bessemer, abundant, insofar, marshes,
# Nearest to writers: fiction, dramatists, hugo, journeying, steinberger, novelists, herzog, dominicans,
# Nearest to behind: landfall, passes, picks, lockport, biscuits, tight, mudslides, explodes,
# Nearest to freedom: publishers, abraham, licencing, hillman, destiny, honeywell, law, refilled,
# Nearest to engine: powered, turbojets, tier, incubator, pickguard, rear, preterite, mieszko,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 4.0245 0.0960 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0256 0.0930 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 4.0490 0.0918 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0692 0.0909 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0853 0.0923 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0327 0.0928 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0396 0.0932 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.1005 0.0946 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0536 0.0925 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0355 0.0908 sec/batch
# Nearest to where: corot, entitle, coronal, smirnov, rundown, ussr, compactification, yarmuk,
# Nearest to see: lexemes, drafts, links, tripling, serbia, rosicrucians, ricin, girdler,
# Nearest to are: normalization, is, consists, non, and, follicles, form, sex,
# Nearest to first: leon, fatou, garde, guevara, gershom, choo, unfretted, lambda,
# Nearest to an: a, caesium, member, domain, functional, infinitesimally, in, fold,
# Nearest to have: constitutive, wasted, eider, linnaeus, earthsea, colonizing, someone, rebekah,
# Nearest to for: computationally, but, they, purer, evaluates, testimonials, shape, regress,
# Nearest to will: anywhere, go, opponent, smarteiffel, kilowatt, hypersonic, reward, wert,
# Nearest to defense: defence, squadron, training, lab, sapphic, numb, perturbed, petered,
# Nearest to centre: towers, kirchner, latgale, seat, sunrise, instantiated, erina, mathematics,
# Nearest to powers: nominates, sundial, divisive, weyl, jubilees, scalemajor, akin, slovenes,
# Nearest to primarily: civilizations, predating, allocates, fp, insofar, bessemer, ameliorated, talent,
# Nearest to writers: fiction, dramatists, hugo, novelists, steinberger, journeying, dominicans, herzog,
# Nearest to behind: landfall, passes, picks, lockport, knocking, rbi, tight, biscuits,
# Nearest to freedom: licencing, publishers, abraham, destiny, honeywell, hillman, concern, law,
# Nearest to engine: powered, turbojets, tier, incubator, pickguard, piston, mieszko, burners,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0517 0.0938 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.1004 0.0957 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0956 0.0924 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0520 0.0939 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0598 0.0930 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0568 0.0943 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0796 0.0930 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0772 0.0919 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0769 0.0931 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0577 0.0920 sec/batch
# Nearest to where: corot, entitle, yarmuk, districts, rundown, birthplace, smirnov, ussr,
# Nearest to see: lexemes, tripling, drafts, links, serbia, rosicrucians, ricin, groningen,
# Nearest to are: normalization, is, consists, sex, form, governs, outside, prostration,
# Nearest to first: leon, guevara, garde, fatou, gershom, veered, grove, unfretted,
# Nearest to an: caesium, a, member, hoping, in, moored, jezebel, domain,
# Nearest to have: constitutive, wasted, earthsea, eider, colonizing, tver, linnaeus, rebekah,
# Nearest to for: but, purer, they, shape, testimonials, computationally, evaluates, farc,
# Nearest to will: go, anywhere, smarteiffel, reward, kilowatt, hypersonic, pup, opponent,
# Nearest to defense: defence, squadron, sapphic, disabilities, training, lab, perturbed, numb,
# Nearest to centre: kirchner, latgale, towers, seat, erina, instantiated, sunrise, mathematics,
# Nearest to powers: nominates, sundial, akin, weyl, divisive, slovenes, olmsted, divinity,
# Nearest to primarily: allocates, civilizations, predating, bessemer, insofar, ameliorated, liverpudlians, oscillations,
# Nearest to writers: dramatists, fiction, hugo, novelists, steinberger, journeying, dominicans, herzog,
# Nearest to behind: landfall, passes, picks, lockport, rbi, knocking, glasnevin, tight,
# Nearest to freedom: licencing, publishers, abraham, destiny, honeywell, hillman, concern, law,
# Nearest to engine: powered, turbojets, pickguard, incubator, mieszko, tier, generators, powerplant,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0549 0.0945 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 4.0142 0.0916 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0414 0.0924 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0647 0.0920 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.1023 0.0922 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1036 0.0913 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1405 0.0917 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0463 0.0937 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0298 0.0911 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0456 0.0921 sec/batch
# Nearest to where: entitle, rundown, corot, in, districts, yarmuk, ussr, compactification,
# Nearest to see: lexemes, links, tripling, serbia, drafts, rosicrucians, groningen, tuvalu,
# Nearest to are: normalization, is, consists, hotchkiss, branches, prostration, non, form,
# Nearest to first: leon, gershom, garde, guevara, fatou, unfretted, choo, grove,
# Nearest to an: a, caesium, member, wildly, domain, hoping, in, jezebel,
# Nearest to have: constitutive, wasted, earthsea, linnaeus, schl, tver, imply, eider,
# Nearest to for: but, evaluates, purer, shape, they, visio, testimonials, computationally,
# Nearest to will: go, anywhere, smarteiffel, reward, hypersonic, pup, kilowatt, opponent,
# Nearest to defense: defence, sapphic, lab, training, disabilities, petered, squadron, numb,
# Nearest to centre: kirchner, towers, latgale, seat, erina, instantiated, sunrise, lut,
# Nearest to powers: nominates, sundial, weyl, akin, olmsted, divisive, jubilees, kurdistan,
# Nearest to primarily: allocates, predating, civilizations, bessemer, ameliorated, rechristened, insofar, departing,
# Nearest to writers: dramatists, novelists, hugo, fiction, dominicans, steinberger, journeying, herzog,
# Nearest to behind: landfall, lockport, picks, passes, rbi, glasnevin, carcinogens, knocking,
# Nearest to freedom: licencing, publishers, abraham, honeywell, destiny, hillman, refilled, supernovae,
# Nearest to engine: powered, turbojets, pickguard, mieszko, tri, incubator, generators, michels,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9853 0.0937 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0325 0.0913 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0334 0.0925 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0132 0.0926 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0646 0.0926 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0688 0.0889 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0150 0.0931 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9805 0.0912 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0284 0.0936 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9779 0.0943 sec/batch
# Nearest to where: entitle, corot, rundown, yarmuk, ussr, districts, compactification, rigged,
# Nearest to see: lexemes, links, rosicrucians, tripling, drafts, serbia, ricin, uses,
# Nearest to are: normalization, prostration, consists, is, non, hotchkiss, branches, foci,
# Nearest to first: leon, guevara, gershom, garde, choo, fatou, division, catal,
# Nearest to an: a, caesium, member, in, wildly, hoping, jezebel, domain,
# Nearest to have: constitutive, wasted, earthsea, tver, imply, eider, guideline, latvians,
# Nearest to for: they, but, shape, evaluates, computationally, purer, testimonials, insider,
# Nearest to will: go, anywhere, reward, smarteiffel, kilowatt, pup, wert, expect,
# Nearest to defense: defence, lab, training, squadron, perturbed, disabilities, sapphic, petered,
# Nearest to centre: towers, latgale, kirchner, seat, erina, instantiated, province, sunrise,
# Nearest to powers: nominates, sundial, akin, weyl, olmsted, jubilees, divisive, divinity,
# Nearest to primarily: allocates, predating, bessemer, civilizations, ameliorated, fp, rechristened, departing,
# Nearest to writers: dramatists, novelists, fiction, hugo, dominicans, steinberger, journeying, herzog,
# Nearest to behind: picks, landfall, passes, lockport, tight, rbi, knocking, glasnevin,
# Nearest to freedom: licencing, publishers, abraham, destiny, honeywell, refilled, hillman, supernovae,
# Nearest to engine: powered, turbojets, pickguard, tri, tier, mieszko, michels, rear,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9813 0.0927 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9324 0.0923 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0302 0.0917 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0039 0.0899 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0206 0.0899 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9910 0.0909 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9037 0.0926 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9780 0.0924 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9300 0.0908 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 4.0094 0.0931 sec/batch
# Nearest to where: entitle, corot, rundown, ussr, smirnov, yarmuk, districts, birthplace,
# Nearest to see: lexemes, links, tripling, rosicrucians, drafts, uses, ricin, http,
# Nearest to are: normalization, is, consists, non, branches, forming, follicles, overlap,
# Nearest to first: leon, division, gershom, fatou, garde, guevara, premierships, unfretted,
# Nearest to an: a, caesium, in, member, wildly, domain, functional, speedup,
# Nearest to have: wasted, someone, constitutive, imply, earthsea, guideline, linnaeus, colonizing,
# Nearest to for: they, shape, purer, but, evaluates, testimonials, computationally, distro,
# Nearest to will: go, reward, anywhere, smarteiffel, kilowatt, opponent, expect, wert,
# Nearest to defense: defence, lab, training, disabilities, squadron, sapphic, perturbed, petered,
# Nearest to centre: towers, latgale, kirchner, seat, erina, instantiated, lut, sunrise,
# Nearest to powers: nominates, sundial, weyl, akin, divisive, olmsted, jubilees, kurdistan,
# Nearest to primarily: predating, allocates, bessemer, insofar, diversified, liverpudlians, nihilist, rechristened,
# Nearest to writers: dramatists, novelists, fiction, hugo, dominicans, steinberger, humanists, journeying,
# Nearest to behind: picks, landfall, passes, tight, rbi, lockport, knocking, glasnevin,
# Nearest to freedom: licencing, publishers, abraham, destiny, honeywell, refilled, concern, law,
# Nearest to engine: powered, turbojets, pickguard, mieszko, michels, tri, jaguar, tier,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9989 0.0928 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9695 0.0928 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9675 0.0914 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0021 0.0926 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0356 0.0925 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9436 0.0940 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9888 0.0942 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9834 0.0919 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9774 0.0904 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9791 0.0910 sec/batch
# Nearest to where: entitle, rundown, smirnov, birthplace, corot, yarmuk, rigged, ussr,
# Nearest to see: links, lexemes, rosicrucians, tripling, uses, drafts, serbia, tuvalu,
# Nearest to are: normalization, consists, is, non, branches, sex, form, outside,
# Nearest to first: leon, gershom, fatou, garde, choo, guevara, unfretted, grove,
# Nearest to an: a, caesium, member, in, domain, jezebel, wildly, ij,
# Nearest to have: constitutive, someone, wasted, imply, guideline, earthsea, tver, linnaeus,
# Nearest to for: they, computationally, distro, but, purer, evaluates, shape, list,
# Nearest to will: anywhere, reward, go, smarteiffel, kilowatt, expect, pup, feu,
# Nearest to defense: defence, lab, ministry, disabilities, perturbed, training, sapphic, squadron,
# Nearest to centre: towers, latgale, kirchner, erina, seat, instantiated, mathematics, lut,
# Nearest to powers: nominates, weyl, sundial, divisive, olmsted, kurdistan, jubilees, akin,
# Nearest to primarily: predating, allocates, bessemer, insofar, rechristened, nihilist, diversified, liverpudlians,
# Nearest to writers: dramatists, novelists, fiction, hugo, dominicans, steinberger, humanists, journeying,
# Nearest to behind: picks, landfall, passes, rbi, lockport, knocking, tight, glasnevin,
# Nearest to freedom: licencing, publishers, abraham, destiny, honeywell, refilled, concern, law,
# Nearest to engine: turbojets, powered, pickguard, piston, mieszko, michels, tri, powerplant,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0078 0.0939 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9795 0.0923 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9896 0.0933 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0158 0.0916 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0139 0.0913 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9858 0.0921 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9762 0.0929 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9538 0.0929 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9967 0.0921 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9949 0.0922 sec/batch
# Nearest to where: entitle, rundown, smirnov, birthplace, districts, there, rigged, corot,
# Nearest to see: links, lexemes, tuvalu, rosicrucians, tripling, serbia, groningen, http,
# Nearest to are: normalization, consists, is, branches, non, outside, overlap, such,
# Nearest to first: leon, gershom, fatou, grove, guevara, garde, oblige, motherland,
# Nearest to an: a, caesium, in, member, domain, wildly, deceptive, hoping,
# Nearest to have: constitutive, imply, someone, wasted, mobiles, latvians, mokume, tver,
# Nearest to for: but, they, list, distro, the, unmik, purer, shape,
# Nearest to will: reward, go, kilowatt, anywhere, smarteiffel, expect, feu, wert,
# Nearest to defense: defence, lab, ministry, sapphic, perturbed, disabilities, squadron, kaleidoscope,
# Nearest to centre: towers, latgale, kirchner, erina, seat, instantiated, province, mathematics,
# Nearest to powers: nominates, weyl, sundial, possessed, akin, olmsted, divisive, jubilees,
# Nearest to primarily: allocates, predating, bessemer, insofar, diversified, ameliorated, nihilist, rechristened,
# Nearest to writers: dramatists, novelists, fiction, hugo, dominicans, steinberger, humanists, philosophers,
# Nearest to behind: landfall, picks, rbi, passes, lockport, glasnevin, tight, angus,
# ...
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.8445 0.0930 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.8493 0.0916 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8706 0.0903 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.9055 0.0929 sec/batch
# Nearest to where: a, rundown, there, in, entitle, esq, position, nf,
# Nearest to see: links, uses, tuvalu, article, is, groningen, lives, for,
# Nearest to are: is, non, and, have, or, the, a, like,
# Nearest to first: the, until, in, nine, and, second, based, was,
# Nearest to an: a, the, in, of, this, is, and, which,
# Nearest to have: are, were, someone, has, other, been, there, these,
# Nearest to for: the, of, also, and, from, in, all, a,
# Nearest to will: yours, should, go, transitory, expect, separators, wants, lottery,
# Nearest to defense: defence, ministry, coordinator, meltdown, kohlrabi, praeger, petered, unconfirmed,
# Nearest to centre: spectacular, latgale, towers, lut, nottinghamshire, erina, kirchner, blocking,
# Nearest to powers: possessed, nominates, redirecting, kurdistan, weyl, sentinels, taking, strau,
# Nearest to primarily: of, predating, other, purposeful, their, thus, allocates, being,
# Nearest to writers: novelists, dramatists, fiction, dominicans, hugo, natives, humanists, autodidacts,
# Nearest to behind: picks, rbi, erik, passes, tight, noll, landfall, tenths,
# Nearest to freedom: freedoms, licencing, concern, flywheels, diketone, riding, ludwik, gaming,
# Nearest to engine: turbojets, powered, compressor, stroke, bomba, encourages, mieszko, hydraulic,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8094 0.0949 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8767 0.0914 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8012 0.0930 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8627 0.0933 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8627 0.0922 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8837 0.0928 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8641 0.0936 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8397 0.0949 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8547 0.0938 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.9121 0.0929 sec/batch
# Nearest to where: in, esq, entitle, rundown, a, there, barns, birthplace,
# Nearest to see: links, tuvalu, groningen, article, uses, is, eglise, of,
# Nearest to are: is, and, non, like, have, or, of, such,
# Nearest to first: until, oblige, based, the, was, in, and, following,
# Nearest to an: a, the, in, of, this, and, which, s,
# Nearest to have: are, were, has, someone, these, been, however, for,
# Nearest to for: the, of, from, and, also, in, all, which,
# Nearest to will: yours, transitory, go, should, expect, revalued, okay, lottery,
# Nearest to defense: defence, ministry, meltdown, coordinator, gendarmerie, petered, praeger, submarine,
# Nearest to centre: latgale, spectacular, kirchner, lut, towers, erina, nad, nottinghamshire,
# Nearest to powers: nominates, possessed, redirecting, weyl, sentinels, kurdistan, taking, ivanov,
# Nearest to primarily: predating, of, purposeful, sorties, allocates, affiliations, acadian, norwegian,
# Nearest to writers: novelists, dramatists, fiction, hugo, dominicans, natives, alumni, humanists,
# Nearest to behind: picks, erik, rbi, usp, passes, noll, tenths, landfall,
# Nearest to freedom: licencing, freedoms, flywheels, diketone, concern, inspections, riding, guarantees,
# Nearest to engine: turbojets, powered, compressor, mieszko, michels, bomba, encourages, stroke,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8756 0.0939 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8303 0.0924 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8554 0.0952 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8444 0.0920 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.9173 0.0928 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8427 0.0921 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9574 0.0919 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8935 0.0913 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9144 0.0907 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8238 0.0935 sec/batch
# Nearest to where: in, rundown, a, esq, there, entitle, position, yarmuk,
# Nearest to see: links, tuvalu, article, groningen, is, uses, eglise, praenomen,
# Nearest to are: is, non, have, and, like, smaller, or, such,
# Nearest to first: until, in, the, second, based, was, nine, and,
# Nearest to an: a, the, in, of, this, generated, s, and,
# Nearest to have: are, were, has, someone, other, been, that, of,
# Nearest to for: the, from, and, of, also, in, as, used,
# Nearest to will: yours, should, go, transitory, expect, okay, separators, revalued,
# Nearest to defense: ministry, defence, praeger, meltdown, petered, gendarmerie, submarine, ptsd,
# Nearest to centre: spectacular, latgale, towers, erina, kirchner, nottinghamshire, nad, province,
# Nearest to powers: possessed, nominates, redirecting, sentinels, kurdistan, weyl, cocaine, invincible,
# Nearest to primarily: of, other, sorties, predating, allocates, purposeful, acadian, consisted,
# Nearest to writers: novelists, dramatists, fiction, hugo, dominicans, natives, alumni, autodidacts,
# Nearest to behind: erik, picks, rbi, landfall, passes, tight, counterfeiting, tenths,
# Nearest to freedom: freedoms, licencing, flywheels, guarantees, inspections, ludwik, recipients, abraham,
# Nearest to engine: turbojets, powered, compressor, mieszko, michels, exhaust, bomba, encourages,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8048 0.0948 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8560 0.0911 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7924 0.0926 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8574 0.0927 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8491 0.0926 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8424 0.0936 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9073 0.0611 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8847 0.0927 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7965 0.0931 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8607 0.0929 sec/batch
# Nearest to where: in, a, esq, entitle, there, rundown, position, student,
# Nearest to see: links, uses, is, article, groningen, tuvalu, praenomen, eglise,
# Nearest to are: is, non, or, like, have, such, of, and,
# Nearest to first: in, until, second, the, and, nyasaland, was, oblige,
# Nearest to an: a, the, in, of, this, as, caesarion, which,
# Nearest to have: were, are, been, that, these, has, of, someone,
# Nearest to for: the, from, as, and, of, also, in, used,
# Nearest to will: yours, should, go, transitory, expect, okay, lottery, said,
# Nearest to defense: defence, ministry, petered, meltdown, gendarmerie, praeger, unconfirmed, submarine,
# Nearest to centre: spectacular, latgale, erina, province, towers, kirchner, nottinghamshire, lut,
# Nearest to powers: possessed, nominates, redirecting, sentinels, weyl, kurdistan, taking, statehood,
# Nearest to primarily: predating, purposeful, of, sorties, allocates, deploying, consisted, hydrofoil,
# Nearest to writers: novelists, dramatists, fiction, dominicans, hugo, natives, autodidacts, alumni,
# Nearest to behind: picks, erik, usp, tight, landfall, tenths, counterfeiting, passes,
# Nearest to freedom: freedoms, licencing, flywheels, abraham, guarantees, ludwik, inspections, diketone,
# Nearest to engine: turbojets, powered, compressor, michels, bomba, mieszko, exhaust, hydraulic,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8088 0.0943 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8218 0.0922 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7720 0.0937 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.8183 0.0903 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8323 0.0889 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8246 0.0920 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8474 0.0932 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7204 0.0913 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8293 0.0922 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8122 0.0935 sec/batch
# Nearest to where: in, a, there, rundown, esq, nf, entitle, position,
# Nearest to see: links, is, uses, groningen, article, of, tuvalu, external,
# Nearest to are: is, non, and, of, or, have, such, like,
# Nearest to first: the, in, until, second, was, following, and, oblige,
# Nearest to an: a, the, in, of, this, and, which, with,
# Nearest to have: are, were, been, has, some, other, someone, for,
# Nearest to for: the, and, of, also, from, in, all, as,
# Nearest to will: yours, should, go, transitory, therefore, they, expect, said,
# Nearest to defense: defence, ministry, unconfirmed, praeger, gendarmerie, meltdown, submarine, petered,
# Nearest to centre: spectacular, towers, latgale, erina, province, nottinghamshire, lut, forwards,
# Nearest to powers: possessed, nominates, redirecting, sentinels, taking, kurdistan, weyl, statehood,
# Nearest to primarily: of, purposeful, predating, being, sorties, other, ones, consisted,
# Nearest to writers: novelists, dramatists, fiction, dominicans, natives, hugo, alumni, autodidacts,
# Nearest to behind: picks, erik, tight, passes, usp, rbi, bladders, tenths,
# Nearest to freedom: freedoms, licencing, flywheels, guarantees, choose, inspections, publishers, riding,
# Nearest to engine: turbojets, powered, compressor, michels, bomba, mieszko, hydraulic, piston,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7674 0.0926 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8299 0.0912 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8606 0.0941 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8127 0.0923 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8288 0.0921 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8821 0.0938 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7949 0.0927 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8127 0.0931 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8331 0.0923 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8360 0.0926 sec/batch
# Nearest to where: in, a, there, rundown, position, entitle, esq, nf,
# Nearest to see: links, article, is, of, uses, groningen, tuvalu, external,
# Nearest to are: is, non, all, of, have, or, these, and,
# Nearest to first: the, in, was, until, and, second, based, following,
# Nearest to an: a, the, in, of, this, is, as, and,
# Nearest to have: are, were, has, that, these, been, for, however,
# Nearest to for: the, of, and, from, in, also, all, as,
# Nearest to will: should, go, yours, therefore, expect, transitory, not, lottery,
# Nearest to defense: defence, ministry, praeger, coordinator, meltdown, unconfirmed, petered, tenure,
# Nearest to centre: spectacular, erina, latgale, towers, forwards, nottinghamshire, lut, kirchner,
# Nearest to powers: nominates, possessed, redirecting, sentinels, kurdistan, taking, weyl, statehood,
# Nearest to primarily: of, norwegian, predating, sorties, purposeful, affiliations, other, thus,
# Nearest to writers: novelists, dramatists, fiction, dominicans, natives, hugo, alumni, humanists,
# Nearest to behind: erik, picks, tight, noll, rbi, passes, usp, counterfeiting,
# Nearest to freedom: freedoms, licencing, flywheels, guarantees, inspections, choose, concern, recipients,
# Nearest to engine: compressor, powered, turbojets, michels, mieszko, bomba, pickguard, exhaust,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.8330 0.0942 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8620 0.0934 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8023 0.0943 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8393 0.0938 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8656 0.0924 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8714 0.0935 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8282 0.0925 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8122 0.0924 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8209 0.0905 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8286 0.0904 sec/batch
# Nearest to where: a, in, there, position, entitle, esq, rundown, nf,
# Nearest to see: links, is, of, article, external, tuvalu, uses, for,
# Nearest to are: is, non, like, of, have, and, or, these,
# Nearest to first: in, until, based, and, the, was, second, next,
# Nearest to an: a, in, the, of, this, is, with, s,
# Nearest to have: are, were, has, been, these, some, for, that,
# Nearest to for: the, of, in, also, from, and, used, as,
# Nearest to will: yours, should, transitory, go, expect, okay, lottery, revalued,
# Nearest to defense: defence, ministry, praeger, meltdown, unconfirmed, gendarmerie, petered, kohlrabi,
# Nearest to centre: latgale, spectacular, erina, province, nottinghamshire, forwards, kirchner, towers,
# Nearest to powers: possessed, nominates, redirecting, sentinels, kurdistan, weyl, taking, statehood,
# Nearest to primarily: of, norwegian, sorties, other, thus, being, impedance, purposeful,
# Nearest to writers: novelists, dramatists, fiction, dominicans, natives, hugo, humanists, autodidacts,
# Nearest to behind: erik, picks, rbi, noll, usp, counterfeiting, passes, tight,
# Nearest to freedom: freedoms, licencing, guarantees, inspections, flywheels, choose, riding, recipients,
# Nearest to engine: powered, compressor, turbojets, michels, pickguard, alfa, encourages, mieszko,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8593 0.0931 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8225 0.0923 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9390 0.0928 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9085 0.0921 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8813 0.0935 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8067 0.0917 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7706 0.0913 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8627 0.0928 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7676 0.0924 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8314 0.0926 sec/batch
# Nearest to where: a, there, in, rundown, entitle, esq, nf, position,
# Nearest to see: links, is, of, uses, article, external, groningen, tuvalu,
# Nearest to are: is, of, non, and, like, or, have, there,
# Nearest to first: until, in, and, second, nyasaland, following, was, the,
# Nearest to an: a, the, in, of, this, s, with, is,
# Nearest to have: were, are, these, that, some, there, has, been,
# Nearest to for: the, from, of, also, and, in, as, used,
# Nearest to will: yours, go, should, transitory, lottery, okay, expect, said,
# Nearest to defense: defence, ministry, praeger, unconfirmed, gendarmerie, meltdown, petered, submarine,
# Nearest to centre: spectacular, latgale, erina, province, towers, forwards, nottinghamshire, nad,
# Nearest to powers: possessed, redirecting, nominates, sentinels, kurdistan, statehood, forcing, weyl,
# Nearest to primarily: of, other, purposeful, being, sorties, norwegian, allocates, those,
# Nearest to writers: novelists, dramatists, fiction, dominicans, natives, hugo, autodidacts, alumni,
# Nearest to behind: erik, picks, marginally, thurman, noll, tight, counterfeiting, passes,
# Nearest to freedom: freedoms, licencing, flywheels, choose, riding, concern, inspections, guarantees,
# Nearest to engine: powered, compressor, turbojets, pickguard, michels, alfa, mieszko, encourages,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8507 0.0943 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8157 0.0930 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
